# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanDlog/Python_Data_Science/blob/main/Pandas_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Aula 1 - Leyendo archivos CSV**
#
# Archivos CSV: https://github.com/alura-es-cursos/1980-Pandas_IO/raw/1980-aula1/1980-aula1.zip

# %% [markdown]
# #### **Importando archivos CSV**

# %%
import pandas as pd

# %%
datos = pd.read_csv('superstore_data.csv')

# %%
datos.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0           218                  1                4                    4
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
datos_punto_coma = pd.read_csv('superstore_data_punto_coma.csv')

# %%
datos_punto_coma.head()
# Out:
#   Id;Year_Birth;Education;Marital_Status;Income;Kidhome;Teenhome;Dt_Customer;Recency;MntWines;MntFruits;MntMeatProducts;MntFishProducts;MntSweetProducts;MntGoldProds;NumDealsPurchases;NumWebPurchases;NumCatalogPurchases;NumStorePurchases;NumWebVisitsMonth;Response;Complain
# 0  1826;1970;Graduation;Divorced;84835;0;0;6/16/2...
# 1  1;1961;Graduation;Single;57091;0;0;6/15/2014;0...
# 2  10476;1958;Graduation;Married;67267;0;1;5/13/2...
# 3  1386;1967;Graduation;Together;32474;1;1;11/5/2...
# 4  5371;1989;Graduation;Single;21474;1;0;8/4/2014...

# %% [markdown]
# #### **Parámetros de la función read_csv**
# Documentación: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
datos_punto_coma = pd.read_csv('superstore_data_punto_coma.csv', sep = ';')

# %%
datos_punto_coma.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0           218                  1                4                    4
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
datos_primeras_lineas = pd.read_csv('superstore_data.csv', nrows = 5)

# %%
datos_primeras_lineas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 0           218                  1                4                    4
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
datos_seleccion = pd.read_csv('superstore_data.csv', usecols = [0, 1, 4])
datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# #### **Escribiendo archivos CSV**
# Documentación: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html

# %%
datos_seleccion.to_csv('clientes_mercado.csv')

# %%
clientes_mercado = pd.read_csv('clientes_mercado.csv')
clientes_mercado
# Out:
#       Unnamed: 0     Id  Year_Birth   Income
# 0              0   1826        1970  84835.0
# 1              1      1        1961  57091.0
# 2              2  10476        1958  67267.0
# 3              3   1386        1967  32474.0
# 4              4   5371        1989  21474.0
# ...          ...    ...         ...      ...
# 2235        2235  10142        1976  66476.0
# 2236        2236   5263        1977  31056.0
# 2237        2237     22        1976  46310.0
# 2238        2238    528        1978  65819.0
# 2239        2239   4070        1969  94871.0
#
# [2240 rows x 4 columns]

# %%
datos_seleccion.to_csv('clientes_mercado.csv', index=False)
datos_mercado = pd.read_csv('clientes_mercado.csv')
datos_mercado
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# #### Solucion a errores de condificaciones

# %%
import chardet

# %%
with open('superstore_data.csv', 'rb') as file:
    print(chardet.detect(file.read()))
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %% [markdown]
# #### Desafio Clase #1
# Archivo CSV: https://raw.githubusercontent.com/alura-es-cursos/1980-Pandas_IO/datos_sus/datos_sus.csv

# %%
import pandas as pd

datos_desafio = pd.read_csv('datos_sus.csv')
datos_desafio.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-42-0e19e918f853> in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 datos_desafio = pd.read_csv('datos_sus.csv')
#       4 datos_desafio.head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      91             # Fail here loudly instead of in cython after reading
#      92             import_optional_dependency("pyarrow")
# ---> 93         self._reader = parsers.TextReader(src, **kwds)
#      94
#      95         self.unnamed_cols = self._reader.unnamed_cols
#
# parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe7 in position 56: invalid continuation byte

# %%
import chardet

with open('datos_sus.csv', 'rb') as file:
  print(chardet.detect(file.read()))
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
datos_desafio = pd.read_csv('datos_sus.csv', sep=';', encoding='ISO-8859-1', skiprows=3, skipfooter=9, engine='python')
datos_desafio.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0             Rondônia   1388528,39   2931283,42   1541682,52   1525314,96
# 1                 Acre    902416,00   1497206,26   1794028,48   1730469,42
# 2             Amazonas   4735529,42   7118990,57   8196635,49   8259378,42
# 3              Roraima    657889,53    777939,31    718688,03    839994,39
# 4                 Pará  18864744,11  19553758,20  21937342,70  20842829,69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953,84   1406150,68   3065279,01   3231494,61   3117178,63  ...
# 1   1819443,92   1828496,00   2511754,59   2089107,14   2275708,53  ...
# 2   7831399,90   8477273,62   9368858,72   9352532,70   9363099,35  ...
# 3    862347,96    832440,66    996693,09    894271,18    910424,17  ...
# 4  23249952,88  23240687,56  24002223,56  23341218,03  25172261,32  ...
#
#       2020/Jul     2020/Ago     2020/Set     2020/Out     2020/Nov  \
# 0  11824687,13  11733307,76  10201985,14   7955139,45   9357946,29
# 1   3915193,20   3640142,82   3391242,21   4044321,44   3276590,10
# 2  19769460,14  18059931,43  17841015,63  16408315,10  19895617,91
# 3   3015488,30   2826486,18   2928043,91   3090313,73   3621031,05
# 4  40804126,43  44385715,88  36820249,47  36965931,34  39004315,80
#
#       2020/Dez     2021/Jan     2021/Fev     2021/Mar          Total
# 0   8880836,55   9266014,59   7730597,04  11023309,47   996411254,68
# 1   3696997,31   3715723,12   3538427,92   4077045,92   450048530,47
# 2  17765167,69  21430289,17  25917134,55  22032176,22  1917247936,05
# 3   3454460,94   3266928,47   3519773,73   3985530,08   328876965,09
# 4  38015145,79  38354682,46  37688314,23  33276392,89  4705309002,29
#
# [5 rows x 161 columns]

# %% [markdown]
# # **Aula 2 - Leyendo archivos Excel**
# Archivos CSV: https://github.com/alura-es-cursos/1980-Pandas_IO/raw/1980-aula2/1980-aula2.zip

# %% [markdown]
# #### Importando archivos Excel

# %%
import pandas as pd

# %%
archivo = 'emisiones_CO2.xlsx'

# %%
datos_co2 = pd.read_excel(archivo)

# %%
datos_co2.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    0.0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    0.0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    0.0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    0.0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    0.0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN

# %%
pd.ExcelFile(archivo).sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %% [markdown]
# #### **Parámetros de la función read_excel**

# %%
percapita = pd.read_excel(archivo, sheet_name='emisiones_percapita')

# %%
percapita.sample(5)
# Out:
#                        País ISO 3166-1 alpha-3   Año      Total  Carbón  \
# 46010         Sudán Del Sur                SSD  1792        NaN     NaN
# 6898   Bosnia Y Herzegovina                BIH  1848        NaN     NaN
# 54288           Suazilandia                SWZ  1910        NaN     NaN
# 31507               Liberia                LBR  1977   832175.0     0.0
# 35073        Islas Marshall                MHL  2007  2305341.0     0.0
#
#           Aceite  Gas  Cemento  Quema  Otros
# 46010        NaN  NaN      NaN    NaN    NaN
# 6898         NaN  NaN      NaN    NaN    NaN
# 54288        NaN  NaN      NaN    NaN    NaN
# 31507   804049.0  0.0  28127.0    0.0    NaN
# 35073  2305341.0  0.0      0.0    0.0    NaN

# %%
fuentes = pd.read_excel(archivo, sheet_name='fuentes')

# %%
fuentes.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año                                 Total  \
# 63099  Global                WLD  2017  CDIAC 2022, BP, and Sum of countries
# 63100  Global                WLD  2018  CDIAC 2022, BP, and Sum of countries
# 63101  Global                WLD  2019  CDIAC 2022, BP, and Sum of countries
# 63102  Global                WLD  2020  CDIAC 2022, BP, and Sum of countries
# 63103  Global                WLD  2021  CDIAC 2022, BP, and Sum of countries
#
#                   Carbón             Aceite                Gas        Cemento  \
# 63099  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63100  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63101  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63102  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63103  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
#
#                     Quema   Otros  \
# 63099  CDIAC 2022 and GCP  [NONE]
# 63100  CDIAC 2022 and GCP  [NONE]
# 63101  CDIAC 2022 and GCP  [NONE]
# 63102  CDIAC 2022 and GCP  [NONE]
# 63103  CDIAC 2022 and GCP  [NONE]
#
#                                               Per Capita
# 63099  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63100  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63101  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63102  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63103  CDIAC 2022, BP, Sum of countries, and UN popul...

# %%
intervalo = pd.read_excel(archivo, sheet_name='emisiones_C02', usecols = 'A:D')

# %%
intervalo
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %%
intervalo2 = pd.read_excel(archivo, sheet_name='emisiones_C02', usecols = 'A:D', nrows = 10)

# %%
intervalo2
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %% [markdown]
# #### **Escribiendo archivos Excel**

# %%
intervalo.to_excel('co2_percapita.xlsx', index = False)

# %%
pd.read_excel('co2_percapita.xlsx')
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %% [markdown]
# #### **Leyendo datos de Google Sheets**
# Link: https://docs.google.com/spreadsheets/d/1xiwUVG3SAUYVx0NjXT_XR8uj5Trt7UtSE5Hj6baZpeo/edit?usp=sharing

# %%
sheet_id = '1xiwUVG3SAUYVx0NjXT_XR8uj5Trt7UtSE5Hj6baZpeo'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
datos_co2_sheets = pd.read_csv(url)

# %%
datos_co2_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año           Total          Carbón  \
# 0      Afganistán                AFG  1750               0             NaN
# 1      Afganistán                AFG  1751               0             NaN
# 2      Afganistán                AFG  1752               0             NaN
# 3      Afganistán                AFG  1753               0             NaN
# 4      Afganistán                AFG  1754               0             NaN
# ...           ...                ...   ...             ...             ...
# 63099      Global                WLD  2017  36,096,739,276  14,506,973,805
# 63100      Global                WLD  2018  36,826,506,600  14,746,830,688
# 63101      Global                WLD  2019  37,082,558,969  14,725,978,025
# 63102      Global                WLD  2020  35,264,085,734  14,174,564,010
# 63103      Global                WLD  2021  37,123,850,352  14,979,598,083
#
#                Aceite            Gas        Cemento        Quema        Otros  \
# 0                 NaN            NaN            NaN          NaN          NaN
# 1                 NaN            NaN            NaN          NaN          NaN
# 2                 NaN            NaN            NaN          NaN          NaN
# 3                 NaN            NaN            NaN          NaN          NaN
# 4                 NaN            NaN            NaN          NaN          NaN
# ...               ...            ...            ...          ...          ...
# 63099  12,242,627,935  7,144,928,128  1,507,923,185  391,992,176  302,294,047
# 63100  12,266,016,285  7,529,846,784  1,569,218,392  412,115,746  302,478,706
# 63101  12,345,653,374  7,647,528,220  1,617,506,786  439,253,991  306,638,573
# 63102  11,191,808,551  7,556,290,283  1,637,537,532  407,583,673  296,301,685
# 63103  11,837,159,116  7,921,829,472  1,672,592,372  416,525,563  296,145,746
#
#       Per Capita
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 63099  4,749,682
# 63100  4,792,753
# 63101  4,775,633
# 63102  4,497,423
# 63103  4,693,699
#
# [63104 rows x 11 columns]

# %%
sheet_id = '1xiwUVG3SAUYVx0NjXT_XR8uj5Trt7UtSE5Hj6baZpeo'
sheet_name = 'emisiones_percapita'
url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
percapita_sheets = pd.read_csv(url_percapita)

# %%
percapita_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 0      Afganistán                AFG  1750        NaN        NaN        NaN
# 1      Afganistán                AFG  1751        NaN        NaN        NaN
# 2      Afganistán                AFG  1752        NaN        NaN        NaN
# 3      Afganistán                AFG  1753        NaN        NaN        NaN
# 4      Afganistán                AFG  1754        NaN        NaN        NaN
# ...           ...                ...   ...        ...        ...        ...
# 63099      Global                WLD  2017  4,749,682  1,908,857  1,610,910
# 63100      Global                WLD  2018  4,792,753  1,919,213  1,596,350
# 63101      Global                WLD  2019  4,775,633  1,896,468  1,589,920
# 63102      Global                WLD  2020  4,497,423  1,807,760  1,427,353
# 63103      Global                WLD  2021  4,693,699  1,893,923  1,496,614
#
#              Gas  Cemento   Quema   Otros
# 0            NaN      NaN     NaN     NaN
# 1            NaN      NaN     NaN     NaN
# 2            NaN      NaN     NaN     NaN
# 3            NaN      NaN     NaN     NaN
# 4            NaN      NaN     NaN     NaN
# ...          ...      ...     ...     ...
# 63099    940,144  198,416  51,579  39,776
# 63100    979,965  204,225  53,634  39,366
# 63101    984,878  208,309  56,569  39,490
# 63102    963,695  208,844  51,981  37,789
# 63103  1,001,585  211,472  52,663  37,443
#
# [63104 rows x 10 columns]

# %%
sheet_id = '1xiwUVG3SAUYVx0NjXT_XR8uj5Trt7UtSE5Hj6baZpeo'
sheet_name = 'fuentes'
url_fuentes = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
fuentes_sheets = pd.read_csv(url_fuentes)

# %%
fuentes_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año  \
# 0      Afganistán                AFG  1750
# 1      Afganistán                AFG  1751
# 2      Afganistán                AFG  1752
# 3      Afganistán                AFG  1753
# 4      Afganistán                AFG  1754
# ...           ...                ...   ...
# 63099      Global                WLD  2017
# 63100      Global                WLD  2018
# 63101      Global                WLD  2019
# 63102      Global                WLD  2020
# 63103      Global                WLD  2021
#
#                                       Total             Carbón  \
# 0                                    [NONE]             [NONE]
# 1                                    [NONE]             [NONE]
# 2                                    [NONE]             [NONE]
# 3                                    [NONE]             [NONE]
# 4                                    [NONE]             [NONE]
# ...                                     ...                ...
# 63099  CDIAC 2022, BP, and Sum of countries  CDIAC 2022 and BP
# 63100  CDIAC 2022, BP, and Sum of countries  CDIAC 2022 and BP
# 63101  CDIAC 2022, BP, and Sum of countries  CDIAC 2022 and BP
# 63102  CDIAC 2022, BP, and Sum of countries  CDIAC 2022 and BP
# 63103  CDIAC 2022, BP, and Sum of countries  CDIAC 2022 and BP
#
#                   Aceite                Gas        Cemento  \
# 0                 [NONE]             [NONE]         [NONE]
# 1                 [NONE]             [NONE]         [NONE]
# 2                 [NONE]             [NONE]         [NONE]
# 3                 [NONE]             [NONE]         [NONE]
# 4                 [NONE]             [NONE]         [NONE]
# ...                  ...                ...            ...
# 63099  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63100  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63101  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63102  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63103  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
#
#                     Quema   Otros  \
# 0                  [NONE]  [NONE]
# 1                  [NONE]  [NONE]
# 2                  [NONE]  [NONE]
# 3                  [NONE]  [NONE]
# 4                  [NONE]  [NONE]
# ...                   ...     ...
# 63099  CDIAC 2022 and GCP  [NONE]
# 63100  CDIAC 2022 and GCP  [NONE]
# 63101  CDIAC 2022 and GCP  [NONE]
# 63102  CDIAC 2022 and GCP  [NONE]
# 63103  CDIAC 2022 and GCP  [NONE]
#
#                                               Per Capita
# 0                                                 [NONE]
# 1                                                 [NONE]
# 2                                                 [NONE]
# 3                                                 [NONE]
# 4                                                 [NONE]
# ...                                                  ...
# 63099  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63100  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63101  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63102  CDIAC 2022, BP, Sum of countries, and UN popul...
# 63103  CDIAC 2022, BP, Sum of countries, and UN popul...
#
# [63104 rows x 11 columns]

# %% [markdown]
# #### Desafio Clase #2
# Link: https://docs.google.com/spreadsheets/d/19YpG6cSC62KUzrhNZaxoTOYQVvcJRtOlHU-wn1aTWmI/edit?usp=sharing

# %%
sheet_id = '19YpG6cSC62KUzrhNZaxoTOYQVvcJRtOlHU-wn1aTWmI'
url_desafio = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
excel_csv = pd.read_csv(url_desafio)

# %%
excel_csv
# Out:
#      Country Name country_code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 210         Samoa          WSM         East Asia & Pacific
# 211   Yemen, Rep.          YEM  Middle East & North Africa
# 212  South Africa          ZAF          Sub-Saharan Africa
# 213        Zambia          ZMB          Sub-Saharan Africa
# 214      Zimbabwe          ZWE          Sub-Saharan Africa
#
#                              Indicator Name           1990           1991  \
# 0    CO2 emissions (metric tons per capita)            NaN            NaN
# 1    CO2 emissions (metric tons per capita)    191,745,115    167,681,579
# 2    CO2 emissions (metric tons per capita)    553,661,955    544,538,649
# 3    CO2 emissions (metric tons per capita)  1,819,541,634    124,281,022
# 4    CO2 emissions (metric tons per capita)  7,521,831,658    723,537,924
# ..                                      ...            ...            ...
# 210  CO2 emissions (metric tons per capita)     55,283,574    609,756,098
# 211  CO2 emissions (metric tons per capita)     56,703,735    690,937,429
# 212  CO2 emissions (metric tons per capita)  6,729,798,587  6,424,621,766
# 213  CO2 emissions (metric tons per capita)    340,929,635    349,232,211
# 214  CO2 emissions (metric tons per capita)  1,585,443,976  1,713,321,439
#
#               1992           1993           1994           1995  ...  \
# 0              NaN            NaN            NaN            NaN  ...
# 1       95,957,742      8,472,111     75,545,827     68,467,956  ...
# 2      543,557,223     70,898,423    836,804,405    912,141,485  ...
# 3      683,699,826    638,307,036    645,355,189    605,436,253  ...
# 4       69,630,787  6,724,177,518  6,541,578,914  6,733,479,486  ...
# ..             ...            ...            ...            ...  ...
# 210    604,266,119    658,221,486    592,806,881    705,674,802  ...
# 211    704,793,064    627,104,927    653,255,714    706,080,534  ...
# 212  6,175,429,944  6,219,193,872  6,215,847,077  6,378,789,568  ...
# 213     33,722,439    289,956,061    241,269,619    234,153,214  ...
# 214  1,694,415,977  1,539,740,958  1,417,186,242    135,661,892  ...
#
#               2011           2012           2013           2014  \
# 0              NaN            NaN            NaN            NaN
# 1       29,650,624    259,295,334     18,562,366    146,235,617
# 2      985,522,312    950,695,879  1,036,293,852  1,099,779,111
# 3      166,942,319    150,324,046  1,533,630,039  1,668,337,371
# 4    5,850,886,105  5,944,654,173  5,942,800,412  5,807,127,723
# ..             ...            ...            ...            ...
# 210  1,066,843,067  1,057,703,002  1,048,701,723  1,092,498,145
# 211    963,978,488    858,490,955  1,106,687,715  1,062,211,282
# 212  7,869,815,906  8,077,957,969  8,138,264,312  8,212,241,156
# 213    217,496,732     27,860,069    284,057,568    304,549,552
# 214     88,488,553    915,734,944    919,824,123    889,104,126
#
#               2015           2016           2017           2018  \
# 0              NaN            NaN            NaN            NaN
# 1      172,896,741    149,789,334    131,694,556      1,632,953
# 2      113,504,405  1,031,811,348     81,330,073    777,674,934
# 3      160,377,515  1,557,664,358  1,788,786,074  1,782,738,948
# 4    6,026,181,822  6,080,600,282  6,104,133,912  6,362,975,399
# ..             ...            ...            ...            ...
# 210  1,240,245,954  1,542,099,372  1,586,830,344  1,478,626,161
# 211    511,361,652    399,363,829    359,621,635    341,068,402
# 212  7,669,937,662  7,563,739,495  7,641,675,086  7,515,678,605
# 213    312,354,964    325,114,844    404,067,778    445,489,133
# 214    899,769,991     78,544,084    726,297,071    857,411,269
#
#               2019         2019.1
# 0              NaN            NaN
# 1      159,824,372    159,824,372
# 2      792,137,069    792,137,069
# 3      169,224,832    169,224,832
# 4    6,481,217,432  6,481,217,432
# ..             ...            ...
# 210  1,522,124,134  1,522,124,134
# 211    380,633,361    380,633,361
# 212  7,507,736,092  7,507,736,092
# 213    380,717,051    380,717,051
# 214     80,297,852     80,297,852
#
# [215 rows x 35 columns]

# %%
excel_csv.to_csv('DataFrame_CSV', index=False)

# %% [markdown]
# # **Aula 3 - Leyendo archivos JSON**
# Archivos JSON: https://app.aluracursos.com/course/pandas-e-s-diferentes-formatos-archivo/task/86149

# %% [markdown]
# #### **Importando archivos JSON**

# %%
import pandas as pd

# %%
datos_pacientes = pd.read_json('pacientes.json')

# %%
datos_pacientes
# Out:
#      ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0              0                 No  16.60      Sí              No  No
# 1              1                 No  20.34      No              No  Sí
# 2              2                 No  26.58      Sí              No  No
# 3              3                 No  24.21      No              No  No
# 4              4                 No  23.71      No              No  No
# ..           ...                ...    ...     ...             ...  ..
# 995          995                 No  28.29      Sí              No  No
# 996          996                 No  25.69      Sí              No  No
# 997          997                 Sí  26.99      No              No  No
# 998          998                 No  44.29      No              No  No
# 999          999                 No  25.83      No              No  No
#
#      Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# 0               3            30                 No       Femenino      55-59
# 1               0             0                 No       Femenino     80 ó +
# 2              20            30                 No      Masculino      65-69
# 3               0             0                 No       Femenino      75-79
# 4              28             0                 Sí       Femenino      40-44
# ..            ...           ...                ...            ...        ...
# 995            10            20                 No       Femenino      65-69
# 996             0             0                 No       Femenino      75-79
# 997             1             0                 No      Masculino      70-74
# 998            30             0                 Sí       Femenino      70-74
# 999             0             0                 No      Masculino      70-74
#
#        Raza Diabetes Actividad_fisica Salud_general  Horas_sueño Asma  \
# 0    Blanca       Sí               Sí     Muy buena            5   Sí
# 1    Blanca       No               Sí     Muy buena            7   No
# 2    Blanca       Sí               Sí     Razonable            8   Sí
# 3    Blanca       No               No         Buena            6   No
# 4    Blanca       No               Sí     Muy buena            8   No
# ..      ...      ...              ...           ...          ...  ...
# 995   Negra       Sí               Sí     Razonable            8   No
# 996  Blanca       No               Sí     Excelente            8   No
# 997  Blanca       No               Sí     Muy buena            8   No
# 998  Blanca       Sí               No         Buena            6   Sí
# 999   Negra       Sí               No     Excelente            7   No
#
#     Enfermedad_renal Cancer_piel
# 0                 No          Sí
# 1                 No          No
# 2                 No          No
# 3                 No          Sí
# 4                 No          No
# ..               ...         ...
# 995               No          No
# 996               No          No
# 997               No          No
# 998               No          No
# 999               No          No
#
# [1000 rows x 19 columns]

# %%
datos_pacientes_2 = pd.read_json('pacientes_2.json')

# %%
datos_pacientes_2
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %% [markdown]
# #### **Normalizando archivos JSON**

# %%
df_normalizado = pd.json_normalize(datos_pacientes_2['Pacientes'])

# %%
df_normalizado
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# #### **Escribiendo archivos JSON**

# %%
df_normalizado.to_json('historico_pacientes_normalizado.json')

# %%
pd.read_json('historico_pacientes_normalizado.json')
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0   1      55-59          Mujer  Blanca  16.60      Sí              No
# 1   2     80 ó +          Mujer  Blanca  20.34      No              No
# 2   3      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# #### Desafio Clase #3

# %%
import requests
import json

# %%
datos_frutas = requests.get('https://fruityvice.com/api/fruit/all')

# %%
resultado = json.loads(datos_frutas.text)

# %%
resultado_2 = pd.json_normalize(resultado)

# %%
resultado_2
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# 11                 Fig   68         Moraceae           Rosales         Ficus
# 12          Gooseberry   69  Grossulariaceae      Saxifragales         Ribes
# 13        Passionfruit   70   Passifloraceae      Malpighiales    Passiflora
# 14                Plum   71         Rosaceae           Rosales        Prunus
# 15              Orange    2         Rutaceae        Sapindales        Citrus
# 16          GreenApple   72         Rosaceae           Rosales         Malus
# 17           Raspberry   23         Rosaceae           Rosales         Rubus
# 18          Watermelon   25    Cucurbitaceae      Cucurbitales     Citrullus
# 19               Lemon   26         Rutaceae        Sapindales        Citrus
# 20               Mango   27    Anacardiaceae        Sapindales     Mangifera
# 21           Blueberry   33         Rosaceae           Rosales      Fragaria
# 22               Apple    6         Rosaceae           Rosales         Malus
# 23               Guava   37        Myrtaceae          Myrtales       Psidium
# 24             Apricot   35         Rosaceae           Rosales        Prunus
# 25               Melon   41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 26           Tangerine   77         Rutaceae        Sapindales        Citrus
# 27            Pitahaya   78        Cactaceae    Caryophyllales     Cactaceae
# 28                Lime   44         Rutaceae        Sapindales        Citrus
# 29         Pomegranate   79       Lythraceae          Myrtales        Punica
# 30         Dragonfruit   80        Cactaceae    Caryophyllales  Selenicereus
# 31               Grape   81         Vitaceae           Vitales         Vitis
# 32               Morus   82         Moraceae           Rosales         Morus
# 33              Feijoa   76        Myrtaceae        Myrtoideae    Sellowiana
# 34             Avocado   84        Lauraceae          Laurales        Persea
# 35           Kiwifruit   85    Actinidiaceae          Ericales     Actinidia
# 36           Cranberry   87        Ericaceae          Ericales     Vaccinium
# 37              Cherry    9         Rosaceae           Rosales        Prunus
# 38               Peach   86         Rosaceae           Rosales        Prunus
# 39           Jackfruit   94         Moraceae           Rosales    Artocarpus
# 40        Horned Melon   95    Cucurbitaceae      Cucurbitales       Cucumis
# 41            Hazelnut   96       Betulaceae           Fagales       Corylus
# 42              Pomelo   98         Rutaceae        Sapindales        Citrus
# 43          Mangosteen   99       Clusiaceae      Malpighiales      Garcinia
# 44             Pumpkin  100    Cucurbitaceae      Cucurbitales     Cucurbita
# 45  Japanese Persimmon  101        Ebenaceae          Ericales     Diospyros
# 46              Papaya   42       Caricaceae       Brassicales        Carica
# 47              Annona  103       Annonaceae           Rosales       Annonas
# 48   Ceylon Gooseberry  104       Salicaceae      Malpighiales      Dovyalis
#
#     nutritions.calories  nutritions.fat  nutritions.sugar  \
# 0                    81            0.00             18.00
# 1                    29            0.40              5.40
# 2                    96            0.20             17.20
# 3                    74            0.20              2.60
# 4                    57            0.10             10.00
# 5                   147            5.30              6.75
# 6                    40            0.40              4.50
# 7                    50            0.34              5.74
# 8                    61            0.50              9.00
# 9                    66            0.44             15.00
# 10                   50            0.12              9.85
# 11                   74            0.30             16.00
# 12                   44            0.60              0.00
# 13                   97            0.70             11.20
# 14                   46            0.28              9.92
# 15                   43            0.20              8.20
# 16                   21            0.10              6.40
# 17                   53            0.70              4.40
# 18                   30            0.20              6.00
# 19                   29            0.30              2.50
# 20                   60            0.38             13.70
# 21                   29            0.40              5.40
# 22                   52            0.40             10.30
# 23                   68            1.00              9.00
# 24                   15            0.10              3.20
# 25                   34            0.00              8.00
# 26                   45            0.40              9.10
# 27                   36            0.40              3.00
# 28                   25            0.10              1.70
# 29                   83            1.20             13.70
# 30                   60            1.50              8.00
# 31                   69            0.16             16.00
# 32                   43            0.39              8.10
# 33                   44            0.40              3.00
# 34                  160           14.66              0.66
# 35                   61            0.50              8.90
# 36                   46            0.10              4.00
# 37                   50            0.30              8.00
# 38                   39            0.25              8.40
# 39                   95            0.00             19.10
# 40                   44            1.26              0.50
# 41                  628           61.00              4.30
# 42                   37            0.00              8.50
# 43                   73            0.58             16.11
# 44                   25            0.30              3.30
# 45                   70            0.20             13.00
# 46                   39            0.30              4.40
# 47                   92            0.29              3.40
# 48                   47            0.30              8.10
#
#     nutritions.carbohydrates  nutritions.protein
# 0                      18.00                0.00
# 1                       5.50                0.80
# 2                      22.00                1.00
# 3                       3.90                0.90
# 4                      15.00                0.40
# 5                      27.10                1.50
# 6                       9.00                1.30
# 7                      11.30                0.75
# 8                      15.00                1.10
# 9                      17.00                0.80
# 10                     13.12                0.54
# 11                     19.00                0.80
# 12                     10.00                0.90
# 13                     22.40                2.20
# 14                     11.40                0.70
# 15                      8.30                1.00
# 16                      3.10                0.40
# 17                     12.00                1.20
# 18                      8.00                0.60
# 19                      9.00                1.10
# 20                     15.00                0.82
# 21                      5.50                0.00
# 22                     11.40                0.30
# 23                     14.00                2.60
# 24                      3.90                0.50
# 25                      8.00                0.00
# 26                      8.30                0.00
# 27                      7.00                1.00
# 28                      8.40                0.30
# 29                     18.70                1.70
# 30                      9.00                9.00
# 31                     18.10                0.72
# 32                      9.80                1.44
# 33                      8.00                0.60
# 34                      8.53                2.00
# 35                     14.60                1.14
# 36                     12.20                0.40
# 37                     12.00                1.00
# 38                      9.50                0.90
# 39                     23.20                1.72
# 40                      7.56                1.78
# 41                     17.00               15.00
# 42                      9.67                0.82
# 43                     17.91                0.41
# 44                      4.60                1.10
# 45                     19.00                0.60
# 46                      5.80                0.50
# 47                     19.10                1.50
# 48                      9.60                1.20

# %% [markdown]
# # **Aula 4 - Leyendo páginas en HTML e XML**
# Archivos HTML: https://github.com/alura-es-cursos/1980-Pandas_IO/raw/1980-aula4/1980-aula4.zip

# %% [markdown]
# #### **Importando páginas web**

# %%
import pandas as pd

# %%
datos_html = pd.read_html('peliculas_wikipedia.html')
datos_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                              Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
#  ..                           ...           ...                   ...
#  95                 The Searchers          1956             John Ford
#  96              Bringing Up Baby          1938          Howard Hawks
#  97                    Unforgiven          1992        Clint Eastwood
#  98  Guess Who's Coming to Dinner          1967        Stanley Kramer
#  99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                        Production companies  Rank
#  0                       RKO Radio Pictures     1
#  1                    Warner Bros. Pictures     2
#  2   Paramount Pictures, Alfran Productions     3
#  3          Selznick International Pictures     4
#  4                         Horizon Pictures     5
#  ..                                     ...   ...
#  95                  C. V. Whitney Pictures    96
#  96                      RKO Radio Pictures    97
#  97                     The Malpaso Company    98
#  98                       Columbia Pictures    99
#  99                   Warner Bros. Pictures   100
#
#  [100 rows x 5 columns],
#            hidevteAFI's 100 Years...100 Movies (1998)  \
#  0  Citizen Kane (1941) Casablanca (1942) The Godf...
#
#          hidevteAFI's 100 Years...100 Movies (1998).1
#  0  Citizen Kane (1941) Casablanca (1942) The Godf...  ]

# %%
type(datos_html)
# Out:
# list

# %%
len(datos_html)
# Out:
# 3

# %%
top_peliculas = datos_html[1]

# %%
top_peliculas
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# 1                    Warner Bros. Pictures     2
# 2   Paramount Pictures, Alfran Productions     3
# 3          Selznick International Pictures     4
# 4                         Horizon Pictures     5
# ..                                     ...   ...
# 95                  C. V. Whitney Pictures    96
# 96                      RKO Radio Pictures    97
# 97                     The Malpaso Company    98
# 98                       Columbia Pictures    99
# 99                   Warner Bros. Pictures   100
#
# [100 rows x 5 columns]

# %% [markdown]
# #### **Escribiendo archivos HTML**

# %%
top_peliculas.to_html('top_peliculas.html', index=False)

# %%
pd.read_html('top_peliculas.html')
# Out:
# [    Unnamed: 0                          Film  Release year  \
#  0            0                  Citizen Kane          1941
#  1            1                    Casablanca          1942
#  2            2                 The Godfather          1972
#  3            3            Gone with the Wind          1939
#  4            4            Lawrence of Arabia          1962
#  ..         ...                           ...           ...
#  95          95                 The Searchers          1956
#  96          96              Bringing Up Baby          1938
#  97          97                    Unforgiven          1992
#  98          98  Guess Who's Coming to Dinner          1967
#  99          99           Yankee Doodle Dandy          1942
#
#                  Director                    Production companies  Rank
#  0           Orson Welles                      RKO Radio Pictures     1
#  1         Michael Curtiz                   Warner Bros. Pictures     2
#  2   Francis Ford Coppola  Paramount Pictures, Alfran Productions     3
#  3         Victor Fleming         Selznick International Pictures     4
#  4             David Lean                        Horizon Pictures     5
#  ..                   ...                                     ...   ...
#  95             John Ford                  C. V. Whitney Pictures    96
#  96          Howard Hawks                      RKO Radio Pictures    97
#  97        Clint Eastwood                     The Malpaso Company    98
#  98        Stanley Kramer                       Columbia Pictures    99
#  99        Michael Curtiz                   Warner Bros. Pictures   100
#
#  [100 rows x 6 columns]]

# %%
top_peliculas.to_csv('top_peliculas_1998.csv', index=False)

# %%
datos = pd.read_csv('top_peliculas_1998.csv')
datos.head()
# Out:
#                  Film  Release year              Director  \
# 0        Citizen Kane          1941          Orson Welles
# 1          Casablanca          1942        Michael Curtiz
# 2       The Godfather          1972  Francis Ford Coppola
# 3  Gone with the Wind          1939        Victor Fleming
# 4  Lawrence of Arabia          1962            David Lean
#
#                      Production companies  Rank
# 0                      RKO Radio Pictures     1
# 1                   Warner Bros. Pictures     2
# 2  Paramount Pictures, Alfran Productions     3
# 3         Selznick International Pictures     4
# 4                        Horizon Pictures     5

# %% [markdown]
# #### **Leyendo/escribiendo archivos XML**

# %%
import pandas as pd

# %%
datos_imdb = pd.read_xml('imdb_top_1000.xml')

# %%
datos_imdb.head(3)
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444

# %%
datos_imdb.to_xml('peliculas_imdb.xml')

# %% [markdown]
# #### Desafio Clase #4
# Link Tabla: https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n

# %%
import pandas as pd

datos_paises = pd.read_html('https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n')

# %%
datos_paises2 = datos_paises[0]
datos_paises2
# Out:
#      N.º                   País (o territorio dependiente)  \
# 0      1                                             India
# 1      2                                        China[12]​
# 2      3                                    Estados Unidos
# 3      4                                         Indonesia
# 4      5                                          Pakistán
# ..   ...                                               ...
# 241  242                           Islas Cocos (Australia)
# 242  243  Islas Ultramarinas Menores de los Estados Unidos
# 243  244                               Islas Pitcairn (RU)
# 244  NaN                                             Mundo
# 245   N°                   País (o territorio dependiente)
#
#     Proyección exponencial de la población al 1/7/2025[7]​  \
# 0                                        1 417 492 000
# 1                                        1 407 934 000
# 2                                          342 181 000
# 3                                          285 783 000
# 4                                          256 204 000
# ..                                                 ...
# 241                                                600
# 242                                                100
# 243                                                 30
# 244                                      8 083 295 000
# 245  Proyección exponencial de la población al 1/7/...
#
#      Total mun- dial (%) Cambio medio anual (%)[8]​  \
# 0                   1754                        090
# 1                   1742                       -005
# 2                    423                        061
# 3                    354                        117
# 4                    317                        256
# ..                   ...                        ...
# 241                  000                        174
# 242                  000                       -496
# 243                  000                       -111
# 244                10000                        103
# 245  Total mun- dial (%)     Cambio medio anual (%)
#
#      Cambio absoluto anual promedio  Cambio medio abs. total anual (%)  \
# 0                        12 692 000                               1524
# 1                        -1 390 000                                  -
# 2                         2 084 000                                250
# 3                         3 337 000                                401
# 4                         6 567 000                                788
# ..                              ...                                ...
# 241                               0                                000
# 242                               0                                000
# 243                               0                                000
# 244                      83 285 000                              10000
# 245  Cambio absoluto anual promedio  Cambio medio abs. total anual (%)
#
#     Años para even- tual du- pli- ca- ción[9]​  \
# 0                                           78
# 1                                            -
# 2                                          114
# 3                                           60
# 4                                           27
# ..                                         ...
# 241                                         40
# 242                                          -
# 243                                          -
# 244                                         68
# 245     Años para even- tual du- pli- ca- ción
#
#     Censo más reciente, última estimación oficial, proyección de la ONU o reloj de población nacional  \
# 0                                        1 417 492 000
# 1                                        1 408 280 000
# 2                                          341 820 000
# 3                                          282 477 584
# 4                                          241 499 431
# ..                                                 ...
# 241                                                593
# 242                                                190
# 243                                                 35
# 244                                      8 202 273 000
# 245  Censo más reciente, última estimación oficial,...
#
#     Fecha de esta última cifra de población en particular (d/mm/aaaa)[10]​  \
# 0                                            1/07/2025
# 1                                           31/12/2024
# 2                                           23/05/2025
# 3                                           30/06/2024
# 4                                            1/03/2023
# ..                                                 ...
# 241                                         11/08/2021
# 242                                          1/04/2010
# 243                                          1/07/2023
# 244                                         23/05/2025
# 245  Fecha de esta última cifra de población en par...
#
#     Tipo[11]​  \
# 0           A
# 1           E
# 2           R
# 3           E
# 4           C
# ..        ...
# 241         C
# 242         C
# 243         E
# 244         R
# 245      Tipo
#
#     Enlace o hipervínculo (usualmente de tipo oficial) de esta última cifra de población
# 0                                      web.archive.org
# 1                                     www.stats.gov.cn
# 2                                       www.census.gov
# 3                    dispendukcapil.acehtimurkab.go.id
# 4                                       www.pbs.gov.pk
# ..                                                 ...
# 241                              www.citypopulation.de
# 242                                   www.statoids.com
# 243                                 www.immigration.pn
# 244                              www.worldometers.info
# 245  Enlace o hipervínculo (usualmente de tipo ofic...
#
# [246 rows x 12 columns]

# %%
datos_paises2.to_html('paises_total.html', index=False)

# %% [markdown]
# # **Aula 5 - Leyendo banco de datos**
# Archivos SQL: https://github.com/alura-es-cursos/1980-Pandas_IO/raw/1980-aula5/1980-aula5.zip

# %% [markdown]
# #### **Creando un banco de datos local**

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect, text

# %%
engine = create_engine('sqlite:///:memory:')

# %% [markdown]
# #### **Escribiendo en un banco de datos**

# %%
import pandas as pd

# %%
archivo = 'clientes_banco.csv'

# %%
datos = pd.read_csv(archivo)

# %%
datos.head()
# Out:
#                  Film  Release year              Director  \
# 0        Citizen Kane          1941          Orson Welles
# 1          Casablanca          1942        Michael Curtiz
# 2       The Godfather          1972  Francis Ford Coppola
# 3  Gone with the Wind          1939        Victor Fleming
# 4  Lawrence of Arabia          1962            David Lean
#
#                      Production companies  Rank
# 0                      RKO Radio Pictures     1
# 1                   Warner Bros. Pictures     2
# 2  Paramount Pictures, Alfran Productions     3
# 3         Selznick International Pictures     4
# 4                        Horizon Pictures     5

# %%
datos.to_sql('clientes', engine, index=False)
# Out:
# 438463

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes', 'clientes.sql']

# %% [markdown]
# #### **Leyendo una consulta SQL**

# %%
query = 'SELECT * FROM clientes WHERE Categoria_de_renta = "Empleado"'

# %%
empleados = pd.read_sql(sql=text(query), con = engine.connect())

# %%
type(empleados)
# Out:
# pandas.core.frame.DataFrame

# %%
empleados
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado                Otro             12
# 2                Empleado           Seguridad              3
# 3                Empleado        Contabilidad              2
# 4                Empleado        Contabilidad              2
# ...                   ...                 ...            ...
# 226054           Empleado                Otro              7
# 226055           Empleado                Otro              7
# 226056           Empleado  Construcción Civil              5
# 226057           Empleado  Construcción Civil              8
# 226058           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                427500.0            1    Departamento alquilado
# 2                112500.0            1  Casa/Departamento propio
# 3                270000.0            1  Casa/Departamento propio
# 4                270000.0            1  Casa/Departamento propio
# ...                   ...          ...                       ...
# 226054           355050.0            1  Casa/Departamento propio
# 226055           355050.0            1  Casa/Departamento propio
# 226056           135000.0            1  Casa/Departamento propio
# 226057           103500.0            0  Casa/Departamento propio
# 226058           121500.0            0  Casa/Departamento propio
#
# [226059 rows x 11 columns]

# %%
empleados.to_sql('empleados', con = engine.connect(), index=False)
# Out:
# 226059

# %%
pd.read_sql_table('empleados', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado                Otro             12
# 2                Empleado           Seguridad              3
# 3                Empleado        Contabilidad              2
# 4                Empleado        Contabilidad              2
# ...                   ...                 ...            ...
# 226054           Empleado                Otro              7
# 226055           Empleado                Otro              7
# 226056           Empleado  Construcción Civil              5
# 226057           Empleado  Construcción Civil              8
# 226058           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                427500.0            1    Departamento alquilado
# 2                112500.0            1  Casa/Departamento propio
# 3                270000.0            1  Casa/Departamento propio
# 4                270000.0            1  Casa/Departamento propio
# ...                   ...          ...                       ...
# 226054           355050.0            1  Casa/Departamento propio
# 226055           355050.0            1  Casa/Departamento propio
# 226056           135000.0            1  Casa/Departamento propio
# 226057           103500.0            0  Casa/Departamento propio
# 226058           121500.0            0  Casa/Departamento propio
#
# [226059 rows x 11 columns]

# %%
pd.read_sql_table('empleados', con = engine.connect(), columns=['ID_Cliente', 'Grado_estudio', 'Rendimiento_anual'])
# Out:
#         ID_Cliente     Grado_estudio  Rendimiento_anual
# 0          5008804    Nivel superior           427500.0
# 1          5008805    Nivel superior           427500.0
# 2          5008806  Nivel intermedio           112500.0
# 3          5008815    Nivel superior           270000.0
# 4          5112956    Nivel superior           270000.0
# ...            ...               ...                ...
# 226054     6837905  Nivel intermedio           355050.0
# 226055     6837906  Nivel intermedio           355050.0
# 226056     6839936  Nivel intermedio           135000.0
# 226057     6840222  Nivel intermedio           103500.0
# 226058     6842885  Nivel intermedio           121500.0
#
# [226059 rows x 3 columns]

# %% [markdown]
# #### **Actualizando un banco de datos**

# %%
query = 'SELECT * FROM clientes'

# %%
pd.read_sql(sql=text(query), con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado                Otro             12
# 2                Empleado           Seguridad              3
# 3        Business Partner              Ventas              8
# 4        Business Partner              Ventas              8
# ...                   ...                 ...            ...
# 438458        Pensionista                Otro              0
# 438459           Empleado  Construcción Civil              8
# 438460   Business Partner              Ventas              1
# 438461        Pensionista                Otro              0
# 438462           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                427500.0            1    Departamento alquilado
# 2                112500.0            1  Casa/Departamento propio
# 3                270000.0            0  Casa/Departamento propio
# 4                270000.0            0  Casa/Departamento propio
# ...                   ...          ...                       ...
# 438458           135000.0            0  Casa/Departamento propio
# 438459           103500.0            0  Casa/Departamento propio
# 438460            54000.0            0       Vive con los padres
# 438461            72000.0            0  Casa/Departamento propio
# 438462           121500.0            0  Casa/Departamento propio
#
# [438463 rows x 11 columns]

# %%
# Borrando resgistros

from sqlalchemy.exc import SQLAlchemyError
query = 'DELETE FROM clientes WHERE ID_Cliente=5008804'
try:
    r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
    print(e)

else:
   print('#Registros borrados: ', r_set.rowcount)
# Out:
# #Registros borrados:  1

# %%
pd.read_sql_table('clientes', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008808    52  Nivel intermedio           Soltero               1
# 3          5008809    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438457     6840104    62  Nivel intermedio        Divorciado               1
# 438458     6840222    43  Nivel intermedio           Soltero               1
# 438459     6841878    22    Nivel superior           Soltero               1
# 438460     6842765    59  Nivel intermedio            Casado               2
# 438461     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado           Seguridad              3
# 2        Business Partner              Ventas              8
# 3        Business Partner              Ventas              8
# 4        Business Partner              Ventas              8
# ...                   ...                 ...            ...
# 438457        Pensionista                Otro              0
# 438458           Empleado  Construcción Civil              8
# 438459   Business Partner              Ventas              1
# 438460        Pensionista                Otro              0
# 438461           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                112500.0            1  Casa/Departamento propio
# 2                270000.0            0  Casa/Departamento propio
# 3                270000.0            0  Casa/Departamento propio
# 4                270000.0            0  Casa/Departamento propio
# ...                   ...          ...                       ...
# 438457           135000.0            0  Casa/Departamento propio
# 438458           103500.0            0  Casa/Departamento propio
# 438459            54000.0            0       Vive con los padres
# 438460            72000.0            0  Casa/Departamento propio
# 438461           121500.0            0  Casa/Departamento propio
#
# [438462 rows x 11 columns]

# %%
# Actualizando Registros

query = 'UPDATE clientes SET Grado_estudio="Nivel superior" WHERE ID_Cliente=5008808'
try:
    r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
    print(e)

else:
   print('#Registros actualizados: ', r_set.rowcount)
# Out:
# #Registros actualizados:  1

# %%
pd.read_sql_table('clientes', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008808    52    Nivel superior           Soltero               1
# 3          5008809    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438457     6840104    62  Nivel intermedio        Divorciado               1
# 438458     6840222    43  Nivel intermedio           Soltero               1
# 438459     6841878    22    Nivel superior           Soltero               1
# 438460     6842765    59  Nivel intermedio            Casado               2
# 438461     6842885    51  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado           Seguridad              3
# 2        Business Partner              Ventas              8
# 3        Business Partner              Ventas              8
# 4        Business Partner              Ventas              8
# ...                   ...                 ...            ...
# 438457        Pensionista                Otro              0
# 438458           Empleado  Construcción Civil              8
# 438459   Business Partner              Ventas              1
# 438460        Pensionista                Otro              0
# 438461           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                112500.0            1  Casa/Departamento propio
# 2                270000.0            0  Casa/Departamento propio
# 3                270000.0            0  Casa/Departamento propio
# 4                270000.0            0  Casa/Departamento propio
# ...                   ...          ...                       ...
# 438457           135000.0            0  Casa/Departamento propio
# 438458           103500.0            0  Casa/Departamento propio
# 438459            54000.0            0       Vive con los padres
# 438460            72000.0            0  Casa/Departamento propio
# 438461           121500.0            0  Casa/Departamento propio
#
# [438462 rows x 11 columns]

# %%
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['clientes', 'clientes.sql', 'empleados']

# %% [markdown]
# #### Desafio Clase #5
# link: https://github.com/alura-es-cursos/1980-Pandas_IO/raw/clientes_banco/clientes_banco.csv.zip

# %%
# 1 - 2

import sqlalchemy
from sqlalchemy import create_engine, MetaData, Table, inspect, text
import pandas as pd

engine = create_engine('sqlite:///:memory:')

archivo = 'clientes_banco.csv'
datos2 = pd.read_csv(archivo)

# %%
datos2.tail()
# Out:
#         ID_Cliente  Edad     Grado_estudio Estado_civil  Tamaño_familia  \
# 117218     5529230    45  Nivel intermedio       Casado               2
# 117219     5529233    45  Nivel intermedio       Casado               2
# 117220     5529234    23  Nivel intermedio      Soltero               1
# 117221     5529235    23  Nivel intermedio      Soltero               1
# 117222     5529242    34  Nivel intermedio       Casado               3
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 117218           Empleado              Ventas              1
# 117219           Empleado              Ventas              1
# 117220   Business Partner  Construcción Civil              1
# 117221   Business Partner  Construcción Civil              1
# 117222           Empleado           Seguridad              1
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 117218           112500.0            0  Casa/Departamento propio
# 117219           112500.0            0  Casa/Departamento propio
# 117220           180000.0            0  Casa/Departamento propio
# 117221           180000.0            0  Casa/Departamento propio
# 117222           135000.0            0                     Casa/

# %%
datos2.to_sql('clientesBancos', engine, index=False)
# Out:
# 117223

# %%
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['clientesBancos']

# %%
# 3

from sqlalchemy.exc import SQLAlchemyError
query = 'UPDATE clientesBancos SET Rendimiento_anual=300000.0 WHERE ID_Cliente=6840104'

try:
  r_set = engine.connect().execute(text(query))

except SQLAlchemyError as e:
  print(e)

else:
  print('#Registros Actualizados: ', r_set.rowcount)
# Out:
# #Registros Actualizados:  0

# %%
query = 'DELETE FROM clientesBancos WHERE ID_Cliente=5008809'

try:
  r_set = engine.connect().execute(text(query))

except SQLAlchemyError as e:
  print(e)

else:
  print('#Registros Eliminados: ', r_set.rowcount)
# Out:
# #Registros Eliminados:  1

# %%
query = 'INSERT INTO clientesBancos (ID_Cliente, Edad, Grado_estudio, Estado_civil, ' \
        'Tamaño_familia, Categoria_de_renta, Ocupacion, Años_empleado, ' \
        'Rendimiento_anual, Tiene_carro, Vivienda) ' \
        'VALUES (6850985, 33, "Doctorado", "Soltero", 1, "Empleado", "TI", ' \
        '2, 290000, 0, "Casa/Departamento propio")'

try:
  r_set = engine.connect().execute(text(query))

except SQLAlchemyError as e:
  print(e)

else:
  print('Registros insetados: ', r_set.rowcount)
# Out:
# Registros insetados:  1

# %%
pd.read_sql_table('clientesBancos', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 117218     5529233    45  Nivel intermedio            Casado               2
# 117219     5529234    23  Nivel intermedio           Soltero               1
# 117220     5529235    23  Nivel intermedio           Soltero               1
# 117221     5529242    34  Nivel intermedio            Casado               3
# 117222     6850985    33         Doctorado           Soltero               1
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 0                Empleado                Otro             12
# 1                Empleado                Otro             12
# 2                Empleado           Seguridad              3
# 3        Business Partner              Ventas              8
# 4        Business Partner              Ventas              8
# ...                   ...                 ...            ...
# 117218           Empleado              Ventas              1
# 117219   Business Partner  Construcción Civil              1
# 117220   Business Partner  Construcción Civil              1
# 117221           Empleado           Seguridad              1
# 117222           Empleado                  TI              2
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 0                427500.0            1    Departamento alquilado
# 1                427500.0            1    Departamento alquilado
# 2                112500.0            1  Casa/Departamento propio
# 3                270000.0            0  Casa/Departamento propio
# 4                270000.0            0  Casa/Departamento propio
# ...                   ...          ...                       ...
# 117218           112500.0            0  Casa/Departamento propio
# 117219           180000.0            0  Casa/Departamento propio
# 117220           180000.0            0  Casa/Departamento propio
# 117221           135000.0            0                     Casa/
# 117222           290000.0            0  Casa/Departamento propio
#
# [117223 rows x 11 columns]
